# %%
import pandas as pd

# %%
matches = pd.read_csv("my_matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W   2   0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W   2   0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W   3   0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L   0   1
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W   3   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk npxg  \
# 0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0  2.6
# 1        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0  2.5
# 2   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0  1.8
# 3  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0  0.9
# 5      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0  2.0
#
#   season       team
# 0   2025  Liverpool
# 1   2025  Liverpool
# 2   2025  Liverpool
# 3   2025  Liverpool
# 5   2025  Liverpool
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (3040, 28)

# %%
38 * 20 * 4
# Out:
# 3040

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   152
# Brentford                   152
# Tottenham Hotspur           152
# Wolverhampton Wanderers     152
# Manchester United           152
# Arsenal                     152
# Everton                     152
# Crystal Palace              152
# West Ham United             152
# Brighton and Hove Albion    152
# Aston Villa                 152
# Newcastle United            152
# Chelsea                     152
# Manchester City             152
# Bournemouth                 114
# Fulham                      114
# Southampton                 114
# Leicester City              114
# Nottingham Forest           114
# Burnley                      76
# Leeds United                 76
# Ipswich Town                 38
# Luton Town                   38
# Sheffield United             38
# Watford                      38
# Norwich City                 38
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     80
# Matchweek 28    80
# Matchweek 23    80
# Matchweek 24    80
# Matchweek 15    80
# Matchweek 25    80
# Matchweek 29    80
# Matchweek 26    80
# Matchweek 27    80
# Matchweek 30    80
# Matchweek 2     80
# Matchweek 31    80
# Matchweek 32    80
# Matchweek 33    80
# Matchweek 34    80
# Matchweek 35    80
# Matchweek 36    80
# Matchweek 37    80
# Matchweek 22    80
# Matchweek 21    80
# Matchweek 20    80
# Matchweek 19    80
# Matchweek 3     80
# Matchweek 4     80
# Matchweek 5     80
# Matchweek 6     80
# Matchweek 7     80
# Matchweek 8     80
# Matchweek 9     80
# Matchweek 10    80
# Matchweek 11    80
# Matchweek 12    80
# Matchweek 13    80
# Matchweek 14    80
# Matchweek 16    80
# Matchweek 17    80
# Matchweek 18    80
# Matchweek 38    80
# Name: count, dtype: int64

# %%
matches.dtypes

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# npxg                    float64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches.head(20)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W   2   0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W   2   0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W   3   0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L   0   1
# 5  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W   3   0
# 7  2024-09-28  17:30  Premier League   Matchweek 6  Sat  Away      W   2   1
# 9  2024-10-05  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 10 2024-10-20  16:30  Premier League   Matchweek 8  Sun  Home      W   2   1
# 12 2024-10-27  16:30  Premier League   Matchweek 9  Sun  Away      D   2   2
# 14 2024-11-02  15:00  Premier League  Matchweek 10  Sat  Home      W   2   1
# 16 2024-11-09  20:00  Premier League  Matchweek 11  Sat  Home      W   2   0
# 17 2024-11-24  14:00  Premier League  Matchweek 12  Sun  Away      W   3   2
# 19 2024-12-01  16:00  Premier League  Matchweek 13  Sun  Home      W   2   0
# 20 2024-12-04  19:30  Premier League  Matchweek 14  Wed  Away      D   3   3
# 22 2024-12-14  15:00  Premier League  Matchweek 16  Sat  Home      D   2   2
# 24 2024-12-22  16:30  Premier League  Matchweek 17  Sun  Away      W   6   3
# 25 2024-12-26  20:00  Premier League  Matchweek 18  Thu  Home      W   3   1
# 26 2024-12-29  17:15  Premier League  Matchweek 19  Sun  Away      W   5   0
# 27 2025-01-05  16:30  Premier League  Matchweek 20  Sun  Home      D   2   2
# 30 2025-01-14  20:00  Premier League  Matchweek 21  Tue  Away      D   1   1
#
#            opponent  ...   fk  pk  npxg  season       team venue_code  \
# 0      Ipswich Town  ...  0.0   0   2.6    2025  Liverpool          0
# 1         Brentford  ...  1.0   0   2.5    2025  Liverpool          1
# 2    Manchester Utd  ...  0.0   0   1.8    2025  Liverpool          0
# 3   Nott'ham Forest  ...  0.0   0   0.9    2025  Liverpool          1
# 5       Bournemouth  ...  0.0   0   2.0    2025  Liverpool          1
# 7            Wolves  ...  1.0   1   1.7    2025  Liverpool          0
# 9    Crystal Palace  ...  0.0   0   1.4    2025  Liverpool          0
# 10          Chelsea  ...  1.0   1   1.1    2025  Liverpool          1
# 12          Arsenal  ...  0.0   0   0.8    2025  Liverpool          0
# 14         Brighton  ...  0.0   0   1.6    2025  Liverpool          1
# 16      Aston Villa  ...  0.0   0   2.0    2025  Liverpool          1
# 17      Southampton  ...  1.0   1   2.3    2025  Liverpool          0
# 19  Manchester City  ...  0.0   1   2.6    2025  Liverpool          1
# 20    Newcastle Utd  ...  0.0   0   1.9    2025  Liverpool          0
# 22           Fulham  ...  0.0   0   2.1    2025  Liverpool          1
# 24        Tottenham  ...  0.0   0   5.6    2025  Liverpool          0
# 25   Leicester City  ...  0.0   0   2.0    2025  Liverpool          1
# 26         West Ham  ...  0.0   0   3.1    2025  Liverpool          0
# 27   Manchester Utd  ...  1.0   1   1.9    2025  Liverpool          1
# 30  Nott'ham Forest  ...  0.0   0   2.0    2025  Liverpool          0
#
#    opp_code hours day_code  target
# 0        10    12        5       2
# 1         3    16        6       2
# 2        16    16        6       2
# 3        19    15        5       0
# 5         2    15        5       2
# 7        25    17        5       2
# 9         7    12        5       2
# 10        6    16        6       2
# 12        0    16        6       1
# 14        4    15        5       2
# 16        1    20        5       2
# 17       21    14        6       2
# 19       15    16        6       2
# 20       17    19        2       1
# 22        9    15        5       1
# 24       22    16        6       2
# 25       12    20        3       2
# 26       24    17        6       2
# 27       16    16        6       1
# 30       19    20        1       1
#
# [20 rows x 33 columns]

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hours"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#matches["target"] = (matches[result] == "W")
matches["target"] = matches["result"].map({
    "L": 0,
    "D": 1, 
    "W": 2
})

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-08-17']

# %%
test = matches[matches["date"] >= '2024-08-17']

# %%
predictors = ["venue_code", "opp_code", "hours", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.4050131926121372

# %%
combine = pd.DataFrame({
    'actual':test['target'], 
    'prediction':preds
})

# %%
pd.crosstab(index=combine["actual"], columns=combine["prediction"])
#    "L" is 0
#    "D" is 1
#    "W" is 2
# Out:
# prediction    0   1    2
# actual
# 0           141  38  107
# 1            88  26   72
# 2           102  44  140

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds, average="weighted")
# Out:
# 0.3853902834657756

# %%
matches = matches.sort_values(["season", "team", "date"]).reset_index(drop=True)

# %%
matches["result_code"] = matches["result"].map({
    "L":0,
    "W":3,
    "D":1
})

# %%
matches["form_5"] = matches.groupby(["season", "team"])["result_code"].transform(lambda x: x.rolling(5, min_periods=1, closed="left").mean())

# %%
matches["form_5"] = matches["form_5"].fillna(1)

# %%
matches["avg_gf_5"] = matches.groupby("team")["gf"].transform(lambda x: x.rolling(5, min_periods=1, closed="left").mean())

# %%
matches["avg_ga_5"] = matches.groupby("team")["ga"].transform(lambda x: x.rolling(5, min_periods=1, closed="left").mean())

# %%
matches["avg_gd_5"] = matches["avg_gf_5"] - matches["avg_ga_5"]

# %%
matches[["avg_gd_5","avg_ga_5","avg_gf_5"]] = matches[["avg_gd_5","avg_ga_5","avg_gf_5"]].fillna(0)

# %%
matches["roll_xg_10"] = matches.groupby("team")["xg"].transform(lambda x: x.rolling(10, min_periods=1, closed="left").mean())

# %%
matches["roll_xg_10"] = matches["roll_xg_10"].fillna(0)

# %%
matches["opp_result_code"] = matches["result"].map({
    "W":0,
    "D":1,
    "L":3
})

# %%
matches["opp_form_5"] = matches.groupby("opp_code")["opp_result_code"].transform(lambda x: x.rolling(5, min_periods=1, closed="left").mean())

# %%
matches["opp_form_5"] = matches["opp_form_5"].fillna(1)

# %%
matches["team_form_5"] = matches["form_5"]

# %%
matches = matches.drop(columns="form_5")

# %%
matches["form_difference_5"] = matches["team_form_5"] - matches["opp_form_5"]

# %%
matches["total_team_points"] = (matches.groupby(["season", "team"])["result_code"].cumsum().shift(fill_value=0))

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'sh', 'sot', 'dist', 'fk',
#        'pk', 'npxg', 'season', 'team', 'venue_code', 'opp_code', 'hours',
#        'day_code', 'target', 'result_code', 'avg_gf_5', 'avg_ga_5', 'avg_gd_5',
#        'roll_xg_10', 'opp_result_code', 'opp_form_5', 'team_form_5',
#        'form_difference_5', 'total_team_points'],
#       dtype='object')

# %%
matches = matches.drop(columns=["attendance", "notes" ])

# %%
matches.head(38)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2021-08-13  20:00  Premier League   Matchweek 1  Fri  Away      L   0   2
# 1  2021-08-22  16:30  Premier League   Matchweek 2  Sun  Home      L   0   2
# 2  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Away      L   0   5
# 3  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1   0
# 4  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1   0
# 5  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W   3   1
# 6  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D   0   0
# 7  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D   2   2
# 8  2021-10-22  20:00  Premier League   Matchweek 9  Fri  Home      W   3   1
# 9  2021-10-30  12:30  Premier League  Matchweek 10  Sat  Away      W   2   0
# 10 2021-11-07  14:00  Premier League  Matchweek 11  Sun  Home      W   1   0
# 11 2021-11-20  17:30  Premier League  Matchweek 12  Sat  Away      L   0   4
# 12 2021-11-27  12:30  Premier League  Matchweek 13  Sat  Home      W   2   0
# 13 2021-12-02  20:15  Premier League  Matchweek 14  Thu  Away      L   2   3
# 14 2021-12-06  20:00  Premier League  Matchweek 15  Mon  Away      L   1   2
# 15 2021-12-11  15:00  Premier League  Matchweek 16  Sat  Home      W   3   0
# 16 2021-12-15  20:00  Premier League  Matchweek 17  Wed  Home      W   2   0
# 17 2021-12-18  17:30  Premier League  Matchweek 18  Sat  Away      W   4   1
# 18 2021-12-26  15:00  Premier League  Matchweek 19  Sun  Away      W   5   0
# 19 2022-01-01  12:30  Premier League  Matchweek 21  Sat  Home      L   1   2
# 20 2022-01-23  14:00  Premier League  Matchweek 23  Sun  Home      D   0   0
# 21 2022-02-10  19:45  Premier League  Matchweek 24  Thu  Away      W   1   0
# 22 2022-02-19  15:00  Premier League  Matchweek 26  Sat  Home      W   2   1
# 23 2022-02-24  19:45  Premier League  Matchweek 20  Thu  Home      W   2   1
# 24 2022-03-06  14:00  Premier League  Matchweek 28  Sun  Away      W   3   2
# 25 2022-03-13  16:30  Premier League  Matchweek 29  Sun  Home      W   2   0
# 26 2022-03-16  20:15  Premier League  Matchweek 27  Wed  Home      L   0   2
# 27 2022-03-19  12:30  Premier League  Matchweek 30  Sat  Away      W   1   0
# 28 2022-04-04  20:00  Premier League  Matchweek 31  Mon  Away      L   0   3
# 29 2022-04-09  15:00  Premier League  Matchweek 32  Sat  Home      L   1   2
# 30 2022-04-16  15:00  Premier League  Matchweek 33  Sat  Away      L   0   1
# 31 2022-04-20  19:45  Premier League  Matchweek 25  Wed  Away      W   4   2
# 32 2022-04-23  12:30  Premier League  Matchweek 34  Sat  Home      W   3   1
# 33 2022-05-01  16:30  Premier League  Matchweek 35  Sun  Away      W   2   1
# 34 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      W   2   1
# 35 2022-05-12  19:45  Premier League  Matchweek 22  Thu  Away      L   0   3
# 36 2022-05-16  20:00  Premier League  Matchweek 37  Mon  Away      L   0   2
# 37 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   5   1
#
#            opponent  ...  result_code  avg_gf_5  avg_ga_5 avg_gd_5 roll_xg_10  \
# 0         Brentford  ...            0      0.00      0.00      0.0   0.000000
# 1           Chelsea  ...            0      0.00      2.00     -2.0   1.300000
# 2   Manchester City  ...            0      0.00      2.00     -2.0   0.800000
# 3      Norwich City  ...            3      0.00      3.00     -3.0   0.600000
# 4           Burnley  ...            3      0.25      2.25     -2.0   1.125000
# 5         Tottenham  ...            3      0.40      1.80     -1.4   1.120000
# 6          Brighton  ...            1      1.00      1.60     -0.6   1.116667
# 7    Crystal Palace  ...            1      1.00      1.20     -0.2   1.014286
# 8       Aston Villa  ...            3      1.40      0.60      0.8   1.100000
# 9    Leicester City  ...            3      1.80      0.80      1.0   1.277778
# 10          Watford  ...            3      2.00      0.80      1.2   1.220000
# 11        Liverpool  ...            0      1.60      0.60      1.0   1.250000
# 12    Newcastle Utd  ...            3      1.60      1.40      0.2   1.260000
# 13   Manchester Utd  ...            0      1.60      1.00      0.6   1.490000
# 14          Everton  ...            0      1.40      1.40      0.0   1.360000
# 15      Southampton  ...            3      1.20      1.80     -0.6   1.350000
# 16         West Ham  ...            3      1.60      1.80     -0.2   1.420000
# 17     Leeds United  ...            3      2.00      1.00      1.0   1.660000
# 18     Norwich City  ...            3      2.40      1.20      1.2   1.840000
# 19  Manchester City  ...            0      3.00      0.60      2.4   1.820000
# 20          Burnley  ...            1      3.00      0.60      2.4   1.830000
# 21           Wolves  ...            3      2.40      0.60      1.8   1.790000
# 22        Brentford  ...            3      2.20      0.60      1.6   1.930000
# 23           Wolves  ...            3      1.80      0.60      1.2   1.850000
# 24          Watford  ...            3      1.20      0.80      0.4   2.020000
# 25   Leicester City  ...            3      1.60      0.80      0.8   2.020000
# 26        Liverpool  ...            0      2.00      0.80      1.2   2.080000
# 27      Aston Villa  ...            3      1.80      1.20      0.6   1.850000
# 28   Crystal Palace  ...            0      1.60      1.00      0.6   1.630000
# 29         Brighton  ...            0      1.20      1.40     -0.2   1.460000
# 30      Southampton  ...            0      0.80      1.40     -0.6   1.570000
# 31          Chelsea  ...            3      0.40      1.60     -1.2   1.620000
# 32   Manchester Utd  ...            3      1.20      1.60     -0.4   1.640000
# 33         West Ham  ...            3      1.60      1.80     -0.2   1.700000
# 34     Leeds United  ...            3      2.00      1.40      0.6   1.480000
# 35        Tottenham  ...            0      2.20      1.20      1.0   1.580000
# 36    Newcastle Utd  ...            0      2.20      1.60      0.6   1.390000
# 37          Everton  ...            3      1.40      1.60     -0.2   1.400000
#
#    opp_result_code opp_form_5 team_form_5  form_difference_5  \
# 0                3        1.0        1.00               0.00
# 1                3        1.0        0.00              -1.00
# 2                3        1.0        0.00              -1.00
# 3                0        1.0        0.00              -1.00
# 4                0        1.0        0.75              -0.25
# 5                0        1.0        1.20               0.20
# 6                1        1.0        1.80               0.80
# 7                1        1.0        2.00               1.00
# 8                0        1.0        2.20               1.20
# 9                0        1.0        2.20               1.20
# 10               0        1.0        2.20               1.20
# 11               3        1.0        2.20               1.20
# 12               0        1.0        2.00               1.00
# 13               3        1.0        2.40               1.40
# 14               3        1.0        1.80               0.80
# 15               0        1.0        1.20               0.20
# 16               0        1.0        1.20               0.20
# 17               0        1.0        1.80               0.80
# 18               0        0.0        1.80               1.80
# 19               3        3.0        2.40              -0.60
# 20               1        0.0        2.40               2.40
# 21               0        1.0        2.00               1.00
# 22               0        3.0        2.00              -1.00
# 23               0        0.0        2.00               2.00
# 24               0        0.0        2.00               2.00
# 25               0        0.0        2.60               2.60
# 26               3        3.0        3.00               0.00
# 27               0        0.0        2.40               2.40
# 28               3        1.0        2.40               1.40
# 29               3        1.0        1.80               0.80
# 30               3        0.0        1.20               1.20
# 31               0        3.0        0.60              -2.40
# 32               0        3.0        1.20              -1.80
# 33               0        0.0        1.20               1.20
# 34               0        0.0        1.80               1.80
# 35               3        0.0        2.40               2.40
# 36               3        0.0        2.40               2.40
# 37               0        3.0        1.80              -1.20
#
#     total_team_points
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   3
# 5                   6
# 6                   9
# 7                  10
# 8                  11
# 9                  14
# 10                 17
# 11                 20
# 12                 20
# 13                 23
# 14                 23
# 15                 23
# 16                 26
# 17                 29
# 18                 32
# 19                 35
# 20                 35
# 21                 36
# 22                 39
# 23                 42
# 24                 45
# 25                 48
# 26                 51
# 27                 51
# 28                 54
# 29                 54
# 30                 54
# 31                 54
# 32                 57
# 33                 60
# 34                 63
# 35                 66
# 36                 66
# 37                 66
#
# [38 rows x 41 columns]

# %%
matches[["season","team", "opponent", "opp_code","sh","sot","xg", "target"]].head()
# Out:
#    season     team         opponent  opp_code    sh  sot   xg  target
# 0    2022  Arsenal        Brentford         3  22.0  4.0  1.3       0
# 1    2022  Arsenal          Chelsea         6   6.0  3.0  0.3       0
# 2    2022  Arsenal  Manchester City        15   1.0  0.0  0.2       0
# 3    2022  Arsenal     Norwich City        18  30.0  6.0  2.7       2
# 4    2022  Arsenal          Burnley         5  13.0  3.0  1.1       2

# %%
matches.shape
# Out:
# (3040, 41)

# %%
matches.dtypes

# %%
train = matches[matches["date"] < '2024-08-17']
test = matches[matches["date"] >= '2024-08-17']

# %%
predictors = ["venue_code", "opp_code", "hours", "day_code", "team_form_5", 
              "avg_gf_5", "avg_ga_5", "avg_gd_5", "roll_xg_10", "opp_form_5", 
              "form_difference_5", "total_team_points", "sot", "sh"]

# %%
def prediction_model(matches, predictors, train, test):

    rf = RandomForestClassifier(n_estimators=200, min_samples_split=10, class_weight="balanced", max_depth=12, random_state=1)

    rf.fit(train[predictors], train["target"])

    preds = rf.predict(test[predictors])

    print("Train size:", len(train))
    print("Test size:", len(test))

    acc = accuracy_score(test["target"], preds)

    combine = pd.DataFrame({
    'actual':test['target'], 
    'prediction':preds
    })

    return acc, preds, combine

# %%
acc, preds, combine = prediction_model(matches, predictors, train, test)
# Out:
# Train size: 2282
# Test size: 758

# %%
acc
# Out:
# 0.5606860158311345

# %%
pd.crosstab(index=combine["actual"], columns=combine["prediction"])
#    "L" is 0
#    "D" is 1
#    "W" is 2
# Out:
# prediction    0   1    2
# actual
# 0           188  25   73
# 1            75  38   73
# 2            63  24  199

# %%
precision_score(test["target"], preds, average="weighted")
# Out:
# 0.542403707902107
