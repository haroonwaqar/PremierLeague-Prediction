# %%
import pandas as pd

# %%
matches = pd.read_csv("my_matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W   2   0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W   2   0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W   3   0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L   0   1
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W   3   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk npxg  \
# 0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0  2.6
# 1        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0  2.5
# 2   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0  1.8
# 3  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0  0.9
# 5      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0  2.0
#
#   season       team
# 0   2025  Liverpool
# ...

# %%
matches.shape
# Out:
# (3040, 28)

# %%
38 * 20 * 4
# Out:
# 3040

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   152
# Brentford                   152
# Tottenham Hotspur           152
# Wolverhampton Wanderers     152
# Manchester United           152
# Arsenal                     152
# Everton                     152
# Crystal Palace              152
# West Ham United             152
# Brighton and Hove Albion    152
# Aston Villa                 152
# Newcastle United            152
# Chelsea                     152
# Manchester City             152
# Bournemouth                 114
# Fulham                      114
# Southampton                 114
# Leicester City              114
# Nottingham Forest           114
# Burnley                      76
# Leeds United                 76
# Ipswich Town                 38
# Luton Town                   38
# Sheffield United             38
# Watford                      38
# Norwich City                 38
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     80
# Matchweek 28    80
# Matchweek 23    80
# Matchweek 24    80
# Matchweek 15    80
# Matchweek 25    80
# Matchweek 29    80
# Matchweek 26    80
# Matchweek 27    80
# Matchweek 30    80
# Matchweek 2     80
# Matchweek 31    80
# Matchweek 32    80
# Matchweek 33    80
# Matchweek 34    80
# Matchweek 35    80
# Matchweek 36    80
# Matchweek 37    80
# Matchweek 22    80
# Matchweek 21    80
# Matchweek 20    80
# Matchweek 19    80
# Matchweek 3     80
# Matchweek 4     80
# Matchweek 5     80
# Matchweek 6     80
# Matchweek 7     80
# Matchweek 8     80
# Matchweek 9     80
# Matchweek 10    80
# Matchweek 11    80
# Matchweek 12    80
# Matchweek 13    80
# Matchweek 14    80
# Matchweek 16    80
# Matchweek 17    80
# Matchweek 18    80
# Matchweek 38    80
# Name: count, dtype: int64

# %%
matches.dtypes

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# npxg                    float64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches.head(20)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W   2   0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W   2   0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W   3   0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L   0   1
# 5  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W   3   0
# 7  2024-09-28  17:30  Premier League   Matchweek 6  Sat  Away      W   2   1
# 9  2024-10-05  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 10 2024-10-20  16:30  Premier League   Matchweek 8  Sun  Home      W   2   1
# 12 2024-10-27  16:30  Premier League   Matchweek 9  Sun  Away      D   2   2
# 14 2024-11-02  15:00  Premier League  Matchweek 10  Sat  Home      W   2   1
# 16 2024-11-09  20:00  Premier League  Matchweek 11  Sat  Home      W   2   0
# ...

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hours"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#matches["target"] = (matches[result] == "W")
matches["target"] = matches["result"].map({
    "L": 0,
    "D": 1, 
    "W": 2
})

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-08-17']

# %%
test = matches[matches["date"] >= '2024-08-17']

# %%
predictors = ["venue_code", "opp_code", "hours", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.4050131926121372

# %%
combine = pd.DataFrame({
    'actual':test['target'], 
    'prediction':preds
})

# %%
pd.crosstab(index=combine["actual"], columns=combine["prediction"])
#    "L" is 0
#    "D" is 1
#    "W" is 2
# Out:
# prediction    0   1    2
# actual
# 0           141  38  107
# 1            88  26   72
# 2           102  44  140

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds, average="weighted")
# Out:
# 0.3853902834657756

# %%
matches = matches.sort_values(["season", "team", "date"]).reset_index(drop=True)

# %%
matches["result_code"] = matches["result"].map({
    "L":0,
    "W":3,
    "D":1
})

# %%
matches["form_5"] = matches.groupby(["season", "team"])["result_code"].transform(lambda x: x.shift().rolling(5, min_periods=1, closed="left").mean())

# %%
matches["form_5"] = matches["form_5"].fillna(1)

# %%
matches["avg_gf_5"] = matches.groupby("team")["gf"].transform(lambda x: x.shift().rolling(5, min_periods=1, closed="left").mean())

# %%
matches["avg_ga_5"] = matches.groupby("team")["ga"].transform(lambda x: x.shift().rolling(5, min_periods=1, closed="left").mean())

# %%
matches["avg_gd_5"] = matches["avg_gf_5"] - matches["avg_ga_5"]

# %%
matches[["avg_gd_5","avg_ga_5","avg_gf_5"]] = matches[["avg_gd_5","avg_ga_5","avg_gf_5"]].fillna(0)

# %%
matches["roll_xg_10"] = matches.groupby("team")["xg"].transform(lambda x: x.shift().rolling(10, min_periods=1, closed="left").mean())

# %%
matches["roll_xg_10"] = matches["roll_xg_10"].fillna(0)

# %%
matches["opp_result_code"] = matches["result"].map({
    "W":0,
    "D":1,
    "L":3
})

# %%
matches["opp_form_5"] = matches.groupby("opp_code")["opp_result_code"].transform(lambda x: x.rolling(5, min_periods=1, closed="left").mean())

# %%
matches["opp_form_5"] = matches["opp_form_5"].fillna(1)

# %%
matches["team_form_5"] = matches["form_5"]

# %%
matches = matches.drop(columns="form_5")

# %%
matches["form_difference_5"] = matches["team_form_5"] - matches["opp_form_5"]

# %%
matches["avg_sh_5"] = matches.groupby(["season","team"])["sh"].transform(lambda x: x.shift().rolling(5, min_periods=1).mean())

# %%
matches["avg_sot_5"] = matches.groupby(["season","team"])["sot"].transform(lambda x: x.shift().rolling(5, min_periods=1).mean())

# %%
matches[["avg_sh_5","avg_sot_5"]] = matches[["avg_sh_5","avg_sot_5"]].fillna(0)

# %%
matches["total_team_points"] = (matches.groupby(["season", "team"])["result_code"].cumsum().shift(fill_value=0))

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'sh', 'sot', 'dist', 'fk',
#        'pk', 'npxg', 'season', 'team', 'venue_code', 'opp_code', 'hours',
#        'day_code', 'target', 'result_code', 'avg_gf_5', 'avg_ga_5', 'avg_gd_5',
#        'roll_xg_10', 'opp_result_code', 'opp_form_5', 'team_form_5',
#        'form_difference_5', 'total_team_points', 'avg_sh_5', 'avg_sot_5'],
#       dtype='object')

# %%
matches = matches.drop(columns=["attendance", "notes" ])

# %%
matches
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2021-08-13  20:00  Premier League   Matchweek 1  Fri  Away      L   0
# 1    2021-08-22  16:30  Premier League   Matchweek 2  Sun  Home      L   0
# 2    2021-08-28  12:30  Premier League   Matchweek 3  Sat  Away      L   0
# 3    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   1
# 4    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W   1
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 3035 2025-04-26  15:00  Premier League  Matchweek 34  Sat  Home      W   3
# 3036 2025-05-02  20:00  Premier League  Matchweek 35  Fri  Away      L   0
# 3037 2025-05-10  15:00  Premier League  Matchweek 36  Sat  Home      L   0
# 3038 2025-05-20  20:00  Premier League  Matchweek 37  Tue  Away      L   2
# 3039 2025-05-25  16:00  Premier League  Matchweek 38  Sun  Home      D   1
#
#       ga         opponent  ...  avg_ga_5  avg_gd_5  roll_xg_10  \
# ...

# %%
matches[["season","team", "opponent", "opp_code","sh","sot","xg", "target"]].head()
# Out:
#    season     team         opponent  opp_code    sh  sot   xg  target
# 0    2022  Arsenal        Brentford         3  22.0  4.0  1.3       0
# 1    2022  Arsenal          Chelsea         6   6.0  3.0  0.3       0
# 2    2022  Arsenal  Manchester City        15   1.0  0.0  0.2       0
# 3    2022  Arsenal     Norwich City        18  30.0  6.0  2.7       2
# 4    2022  Arsenal          Burnley         5  13.0  3.0  1.1       2

# %%
matches.shape
# Out:
# (3040, 43)

# %%
matches.dtypes

# %%
train = matches[matches["date"] < '2024-08-17']
test = matches[matches["date"] >= '2024-08-17']

# %%
predictors = ["venue_code", "opp_code", "hours", "day_code", "team_form_5", 
              "avg_gf_5", "avg_ga_5", "avg_gd_5", "roll_xg_10", "opp_form_5", 
              "form_difference_5", "avg_sh_5", "avg_sot_5", "total_team_points"]

# %%
def prediction_model(matches, predictors, train, test):

    rf = RandomForestClassifier(n_estimators=200, min_samples_split=10, class_weight="balanced", max_depth=12, random_state=1)

    rf.fit(train[predictors], train["target"])

    preds = rf.predict(test[predictors])

    print("Train size:", len(train))
    print("Test size:", len(test))

    acc = accuracy_score(test["target"], preds)

    combine = pd.DataFrame({
    'actual':test['target'], 
    'prediction':preds
    })

    return acc, preds, combine

# %%
acc, preds, combine = prediction_model(matches, predictors, train, test)
# Out:
# Train size: 2282
# Test size: 758

# %%
acc
# Out:
# 0.4762532981530343

# %%
pd.crosstab(index=combine["actual"], columns=combine["prediction"])
#    "L" is 0
#    "D" is 1
#    "W" is 2
# Out:
# prediction    0   1    2
# actual
# 0           157  35   94
# 1            81  20   85
# 2            82  20  184

# %%
precision_score(test["target"], preds, average="weighted")
# Out:
# 0.4418053390101543
